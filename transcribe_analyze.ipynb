# %% [markdown]
# ## Load libs

# %%
import speech_recognition as sr
from os import path
import re
import pydub
from pydub import AudioSegment
from pydub.silence import split_on_silence, detect_nonsilent, detect_silence
from pydub.playback import play

# %% [markdown]
# ## Open audio file

# %%
AUDIO_FILE = "./October4thGoogleEvent_short.flac"

r = sr.Recognizer()
with sr.AudioFile(AUDIO_FILE) as source:
    audio = r.record(source)
    print('Reading audio file... done')
# Out:
# Reading audio file... done

# %% [markdown]
# ## Function for transcribing audio/video file

# %%
def speech_to_text(AUDIO_FILE):
    r = sr.Recognizer()
    with sr.AudioFile(AUDIO_FILE) as source:
        audio = r.record(source)

    text = None
    try:
        # for testing purposes, we're just using the default API key
        # to use another API key, use `r.recognize_google(audio, key="GOOGLE_SPEECH_RECOGNITION_API_KEY")`
        # instead of `r.recognize_google(audio)`
        text = r.recognize_google(audio)
    except sr.UnknownValueError:
        print("Google Speech Recognition could not understand audio")
    except sr.RequestError as e:
        print("Could not request results from Google Speech Recognition service; {0}".format(e))
    
    return text

# %% [markdown]
# ## Function for counting words/phrases in transcript

# %%
def count_phrase(phrase, text):
    all_matches = re.findall(phrase, text)
    return len(all_matches)

# %%
sound = AudioSegment.from_file(AUDIO_FILE, format="flac")

# %%
complete_text = ''

length_segment = 15000
n_segments = int(sound.duration_seconds * 1000 / length_segment + 1)
segments = [(x*length_segment, (x+1)*length_segment) for x in range(0, n_segments)]

for start, end in segments:
    start = max(0, start-0)
    sound_this = sound[start:end]
    sound_this.export('tmp.wav', format="wav")
    
    text = speech_to_text('tmp.wav')
    complete_text += text + ' '
    
    print(start, end)
    print(text)
    #play(sound_this)
# Out:
# 0 15000
# we are going to use machine learning we understand location data we try to understand paddle surfing and the colour shows the density of parking and we can analyse it throughout the day and predict parking difficulty and then Google
# 15000 30000
# give you options a simple example but it's the kind of everyday use case for which we are using machine learning to make a difference the best example I can think of what we've talked before is Google translation
# 30000 45000
# I literally remember many years ago Adam translation in Chrome and making it automatic so if you land in a page different from your language we do that for you fast forward to today with the power of machine learning and neural machine
# 45000 60000
# station visa or 2 million translations in many many languages every single day to me shows the power of staying at a problem constantly using computer science to make it better and seeing users respond to Xscape
# 60000 75000
# this is why we are excited about the shift from a mobile first to AI first well it's not just about applying machine learning in their products but it's radically rethinking
# 75000 90000
# how computing should work on a higher level in an AI first world I believe computer should an app to help people live their lives rather than people having to adapt to computers and so we think about
# 90000 105000
# 4 core attributes as part of the experience first people should be able to interact with computing in a natural and seamlessly mobile took the stupidness Direction with multi-touch but
# 105000 120000
# increasingly it needs to be conversational sensory we need to be able to use her voice gestures and wishing to make the experience much more seamless it is going to be
# 120000 135000
# computing is going to be on the phone be there in many screens around you when you need it working for you we think it needs to be thoughtfully contact you
# 135000 150000
# Davis Ltd Calne

# %%
count_phrase(r'machine learning', complete_text)
# Out:
# 4

# %%
count_phrase(r' AI first', complete_text)
# Out:
# 2

# %%
count_phrase(r'mobile first', complete_text)
# Out:
# 1

# %%
detect_silence(sound, min_silence_len=100, silence_thresh=-25)
# Out:
# [[0, 6212], [6240, 24281]]

# %%
sound[0:6202]
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>
